# %%
#Bar plot is cooman type of graphic its represent relation between 
#catogoriacl and numrical data

# %%
import matplotlib.pyplot as plt
import numpy as np
x=np.array(["Apply","banana","cherry","kiwi"])
y=np.array([50,60,70,100])
plt.bar(x,y)
plt.show()

#MATPLOTLIB IS A PYTHONLIBRARY FOR CREATING STATIC ,ANIMATED AND INTERACTIVE
#VISVLIZATION ITS PROVIDES WIDE RANGE OF FUNCTINALITIES FOR :2D VISVLIZATION

#Numpy (numrical python )is a fundamental for numrical and scientific computing in python
#its support multidimensial array
#.bar
#matlab is tool advance tool which is used for arronatical and electric program

# %%
#python operators(shift oprators)
x=8
x>>=2
print(x)
# Out:
# 2
